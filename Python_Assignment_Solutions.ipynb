# %% [markdown]
# # Python for AI & ML - Assessment Solutions

# %% [markdown]
# ## 1. Filtering Data

# %%
readings = [25.1, 18.5, 32.0, 15.2, 28.9]
for r in readings:
    if r > 20:
        print(r)
# Out:
# 25.1
# 32.0
# 28.9

# %% [markdown]
# ## 2. Mean

# %%
scores = [80, 90, 70, 100]
average = sum(scores) / len(scores)
print(average)
# Out:
# 85.0

# %% [markdown]
# ## 3. String Formatting

# %%
accuracy = 0.95
model_name = "Neural Network"
print(f"The {model_name} model has an accuracy of {accuracy*100}%.")
# Out:
# The Neural Network model has an accuracy of 95.0%.

# %% [markdown]
# ## 4. List Operations

# %%
features = ["height", "weight"]
features.append("age")
features.remove("height")
print(features)
# Out:
# ['weight', 'age']

# %% [markdown]
# ## 5. Boolean Logic

# %%
x = 0.5
if 0 <= x <= 1:
    print("Valid")
# Out:
# Valid

# %% [markdown]
# ## 6. Import NumPy

# %%
import numpy as np

# %% [markdown]
# ## 7. Create Array

# %%
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# ## 8. Array Shape

# %%
import numpy as np

data = np.zeros((10, 3))
print(data.shape)
# Out:
# (10, 3)

# %% [markdown]
# ## 9. Simple Scaling

# %%
prices = [100,200,300]
scaled_prices = [p/100 for p in prices]
print(scaled_prices)
# Out:
# [1.0, 2.0, 3.0]

# %% [markdown]
# ## 10. Find Max

# %%
errors = [0.5,0.1,0.9,0.2]
print(max(errors))
# Out:
# 0.9
